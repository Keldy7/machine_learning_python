# %% [markdown]
# # 1. Importation des librairies

# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.metrics import precision_score, recall_score, f1_score, accuracy_score
# Out:
# UsageError: Line magic function `%` not found.

# %% [markdown]
# # 2. Chargement du dataset

# %%
donnees = pd.read_csv('./Fichiers de données/MalwareArtifacts.csv.xls')

# %%
donnees
# Out:
#         AddressOfEntryPoint  MajorLinkerVersion  MajorImageVersion  \
# 0                     10407                   9                  6
# 1                      5354                   9                  6
# 2                     58807                   9                  6
# 3                     25166                   9                  6
# 4                     70387                   9                  6
# ...                     ...                 ...                ...
# 137439               123291                  11                  0
# 137440                40000                   2                  6
# 137441                59610                  10                  0
# 137442                51216                   2                  0
# 137443                22731                  11                  0
#
#         MajorOperatingSystemVersion  DllCharacteristics  SizeOfStackReserve  \
# 0                                 6               33088              262144
# ...

# %% [markdown]
# # 3. Prétraitement des données

# %%
donnees.shape
# Out:
# (137444, 9)

# %%
# Nature des données
donnees.info()

# Statistiques descriptives
donnees.describe()

# Suppression des colonnes manquantes
donnees.dropna()

# Suppression des doublons
donnees.drop_duplicates(inplace=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 137444 entries, 0 to 137443
# Data columns (total 9 columns):
#  #   Column                       Non-Null Count   Dtype
# ---  ------                       --------------   -----
#  0   AddressOfEntryPoint          137444 non-null  int64
#  1   MajorLinkerVersion           137444 non-null  int64
#  2   MajorImageVersion            137444 non-null  int64
#  3   MajorOperatingSystemVersion  137444 non-null  int64
#  4   DllCharacteristics           137444 non-null  int64
#  5   SizeOfStackReserve           137444 non-null  int64
#  6   NumberOfSections             137444 non-null  int64
#  7   ResourceSize                 137444 non-null  int64
#  8   legitimate                   137444 non-null  int64
# dtypes: int64(9)
# memory usage: 9.4 MB

# %%
donnees.shape
# Out:
# (32670, 9)

# %% [markdown]
# # 4. Corrélation entre les différentes variables

# %%
donnees.corr()
# Out:
#                              AddressOfEntryPoint  MajorLinkerVersion  \
# AddressOfEntryPoint                     1.000000           -0.002336
# MajorLinkerVersion                     -0.002336            1.000000
# MajorImageVersion                       0.003402            0.017067
# MajorOperatingSystemVersion            -0.000367           -0.001522
# DllCharacteristics                      0.007295            0.062685
# SizeOfStackReserve                      0.012757           -0.042769
# NumberOfSections                        0.017451            0.036357
# ResourceSize                            0.001283           -0.006351
# legitimate                             -0.029986            0.072118
#
#                              MajorImageVersion  MajorOperatingSystemVersion  \
# AddressOfEntryPoint                   0.003402                    -0.000367
# MajorLinkerVersion                    0.017067                    -0.001522
# ...

# %% [markdown]
# # 5. Séparation du dataset en données d'entraînement et de test

# %%
# Extraction du feature et target
X = donnees[['AddressOfEntryPoint', 'MajorLinkerVersion', 'MajorImageVersion', 'MajorOperatingSystemVersion', 'DllCharacteristics', 'SizeOfStackReserve', 'NumberOfSections', 'ResourceSize']]
y = donnees['legitimate']

# %%
# Données en ensembles d'entraînement et de test
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)
